# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("//home//sighwalker//codes//crux-ml-workshop//Week 2-3 - Advanced Classification//2022A3PS0610H_TanayGarde_Week2-3//train.csv")
tf = pd.read_csv("//home//sighwalker//codes//crux-ml-workshop/Week 2-3 - Advanced Classification//2022A3PS0610H_TanayGarde_Week2-3//test.csv")
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  46906    819.195       312.005016       192.610967      1.619871
# 1  34079    698.752       267.050685       162.927756      1.639074
# 2  51453    891.790       360.178529       182.843773      1.969870
# 3  44725    792.243       293.196459       194.903183      1.504318
# 4  52492    868.092       336.071881       199.217295      1.686961
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.786702       47360     244.382025  0.711927  0.990414   0.878342
# 1      0.792324       34540     208.304418  0.675420  0.986653   0.877103
# 2      0.861565       52164     255.953110  0.708875  0.986370   0.813009
# 3      0.747063       45258     238.632853  0.720906  0.988223   0.895454
# 4      0.805363       53087     258.524448  0.686682  0.988792   0.875329
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# ...

# %%
df = df.replace(' ?',np.nan)
tf = tf.replace(' ?',np.nan)
x = df.iloc[:,1:16]
y = df.iloc[:,16]
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
np.array(x_scaled)
xt = tf.iloc[:,1:16]
xt_scaled = min_max_scaler.fit_transform(xt)
np.array(xt_scaled)
# Out:
# array([[0.14821646, 0.13795034, 0.25944532, ..., 0.6112214 , 0.69753409,
#         0.9917695 ],
#        [0.38614602, 0.33636012, 0.35294247, ..., 0.25893731, 0.4033318 ,
#         0.68515176],
#        [0.125959  , 0.11675482, 0.21983393, ..., 0.63302906, 0.66995487,
#         0.96475404],
#        ...,
#        [0.32692447, 0.43352531, 0.19269761, ..., 0.07992546, 0.04409348,
#         0.87615422],
#        [0.12301918, 0.15397235, 0.14400048, ..., 0.42242518, 0.39490472,
#         0.95547608],
#        [0.19008595, 0.23984748, 0.16742595, ..., 0.27244225, 0.26727787,
#         0.95248012]])

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.001, random_state=None)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100, random_state=0)


rfc.fit(X_train, y_train)


y_pred = rfc.predict(xt_scaled)

# %%
submission = pd.read_csv("/home/sighwalker/codes/crux-ml-workshop/Week 2-3 - Advanced Classification/2022A3PS0610H_TanayGarde_Week2-3/test.csv",header=0)

my_submission = pd.DataFrame({'Class': y_pred})

my_submission.to_csv('submission.csv', index=False)
